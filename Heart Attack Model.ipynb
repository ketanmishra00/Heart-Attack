# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns

# %% [markdown]
# # Reading data

# %%
df = pd.read_csv(r"C:\Users\Ketan\downloads\heart.csv")
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# # DATA VISUALISATION

# %%
df["output"].value_counts()
# Out:
# 1    165
# 0    138
# Name: output, dtype: int64

# %%
df.hist(column='age', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ADCA082760>]],
#       dtype=object)

# %%
df.hist(column='sex', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ADCA0827F0>]],
#       dtype=object)

# %%
df.hist(column='chol', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ADCA957250>]],
#       dtype=object)

# %%
sns.relplot(x='age',y='chol',hue='output',size='trtbps',col='sex',data=df)

# %%
sns.relplot(x='age',y='trtbps',hue = "output",size ='chol',col = 'sex',data = df)

# %%
sns.relplot(x='trtbps',y='chol',hue ='output',data =df)

# %%
sns.relplot(y='thalachh',x='age',hue='output',data=df)

# %%
sns.relplot(x='trtbps',y='chol',hue ='sex',size='age',col ='output',data = df)

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
ax = sns.catplot(x='restecg',kind= 'count',data=df,orient="h")
ax.fig.autofmt_xdate()

# %%
sns.catplot(x="age",y="sex",kind='box',data=df)

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
ax = sns.catplot(x='cp',y='age',hue='output',kind='point',data=df)
ax.fig.autofmt_xdate()

# %%
ax = sns.catplot(x='exng',y='age',hue='output',kind='point',data=df)
ax.fig.autofmt_xdate()

# %% [markdown]
# # MODELING

# %%
x = df.drop(['output'],axis=1).values

# %%
y= df['output'].values

# %%
print(x)
# Out:
# [[63.  1.  3. ...  0.  0.  1.]
#  [37.  1.  2. ...  0.  0.  2.]
#  [41.  0.  1. ...  2.  0.  2.]
#  ...
#  [68.  1.  0. ...  1.  2.  3.]
#  [57.  1.  0. ...  1.  1.  3.]
#  [57.  0.  1. ...  1.  1.  2.]]

# %% [markdown]
# # NORMALIZATION

# %%
x = preprocessing.StandardScaler().fit(x).transform(x.astype(float))
x[0:5]
# Out:
# array([[ 0.9521966 ,  0.68100522,  1.97312292,  0.76395577, -0.25633371,
#          2.394438  , -1.00583187,  0.01544279, -0.69663055,  1.08733806,
#         -2.27457861, -0.71442887, -2.14887271],
#        [-1.91531289,  0.68100522,  1.00257707, -0.09273778,  0.07219949,
#         -0.41763453,  0.89896224,  1.63347147, -0.69663055,  2.12257273,
#         -2.27457861, -0.71442887, -0.51292188],
#        [-1.47415758, -1.46841752,  0.03203122, -0.09273778, -0.81677269,
#         -0.41763453, -1.00583187,  0.97751389, -0.69663055,  0.31091206,
#          0.97635214, -0.71442887, -0.51292188],
#        [ 0.18017482,  0.68100522,  0.03203122, -0.66386682, -0.19835726,
#         -0.41763453,  0.89896224,  1.23989692, -0.69663055, -0.20670527,
#          0.97635214, -0.71442887, -0.51292188],
#        [ 0.29046364, -1.46841752, -0.93851463, -0.66386682,  2.08204965,
#         -0.41763453,  0.89896224,  0.58393935,  1.43548113, -0.37924438,
# ...

# %% [markdown]
# # Spliting the data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=45)

# %% [markdown]
# # USING KNN

# %%
neighbors = np.arange(1, 9)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))
 
# Loop over K values
for i, k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
     
    # Compute training and test data accuracy
    train_accuracy[i] = knn.score(x_train, y_train)
    test_accuracy[i] = knn.score(x_test, y_test)
 
# Generate plot
plt.plot(neighbors, test_accuracy, label = 'Testing dataset Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training dataset Accuracy')
 
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Now we know that now at k=7 the acuracy is best

# %% [markdown]
# # MODELING

# %%
from sklearn.neighbors import KNeighborsClassifier#Import knearest neighbors Classifier model
knn= KNeighborsClassifier(n_neighbors = 7)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)

# %%
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8688524590163934

# %% [markdown]
# # Prediction

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[19  4]
#  [ 4 34]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83        23
#            1       0.89      0.89      0.89        38
#
#     accuracy                           0.87        61
#    macro avg       0.86      0.86      0.86        61
# weighted avg       0.87      0.87      0.87        61

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, knn.predict(x_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Train set Accuracy:  0.8760330578512396
# Test set Accuracy:  0.8688524590163934
